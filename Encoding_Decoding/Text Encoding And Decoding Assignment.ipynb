# %%
txt = '''Coronavirus disease 2019 (COVID-19), also known as the coronavirus, or COVID, is a contagious disease caused by severe acute respiratory syndrome coronavirus 2 (SARS-CoV-2). The first known case was identified in Wuhan, China, in December 2019.[7] The disease has since spread worldwide, leading to an ongoing pandemic.[8]

Symptoms of COVID-19 are variable, but often include fever,[9] cough, headache,[10] fatigue, breathing difficulties, and loss of smell and taste.[11][12] Symptoms may begin one to fourteen days after exposure to the virus. At least a third of people who are infected do not develop noticeable symptoms.[13] Of those people who develop noticeable symptoms enough to be classed as patients, most (81%) develop mild to moderate symptoms (up to mild pneumonia), while 14% develop severe symptoms (dyspnea, hypoxia, or more than 50% lung involvement on imaging), and 5% suffer critical symptoms (respiratory failure, shock, or multiorgan dysfunction).[14] Older people are at a higher risk of developing severe symptoms. Some people continue to experience a range of effects (long COVID) for months after recovery, and damage to organs has been observed.[15] Multi-year studies are underway to further investigate the long-term effects of the disease.[15]

Transmission of COVID-19 occurs when people are exp)(osed to virus-containing respiratory droplets and airborne particles exhaled by an infected person.[16][17] Those particles may be inhaled or may reach the mouth, nose, or eyes of a person through touching or direct deposition (i.e. being coughed on).[16] The risk of infection is highest when people are in close proximity for a long time, but particles can be inhaled over longer distances, particularly indoors in poorly ventilated and crowded spaces.[16][18] In those conditions small particles can remain suspended in the air for minutes to hours.[16] Touching a contaminated surface or object may lead to infection although this does not contribute substantially to transmission.[16][19] People who are infected can transmit the virus to another person up to two days before they themselves show symptoms, as can people who do not experience symptoms.[20][21] People remain infectious for up to ten days after the onset of symptoms in moderate cases and up to twenty days in severe cases.[22]

Several testing me)(thods have been developed to diagnose the disease. The standard diagnostic method is by detection of the virus' nucleic acid by real-time reverse transcription polymerase chain reaction (rRT-PCR), transcription-mediated amplification (TMA), or by reverse transcription loop-mediated isothermal amplification (RT-LAMP) from a nasopharyngeal swab.

Preventive measures include physical or social distancing, quarantining, ventilation of indoor spaces, covering coughs and sneezes, hand washing, and keeping unwashed hands away from the face. The use of face masks or coverings has been recommended in public settings to minimize the risk of transmissions. Several vaccines have been developed and many countries have initiated mass vaccination campaigns.

Although work is underway to develop drugs that inhibit the virus, the primary treatment is symptomatic. Management involves the treatment of symptoms, supportive care, isolation, and experimental measures.'''

# %%
txt = txt.lower()

for i in range(7,23):
    ref = "[" + str(i) + "]"
    txt = txt.replace(ref, "")
    
txt = txt.replace('\n\n','')

for i in '!@#$%^&*_~`{}:"<>"+().,1234567890-':
    txt = txt.replace(i, '')

# %%
txt
# Out:
# "coronavirus disease  covid also known as the coronavirus or covid is a contagious disease caused by severe acute respiratory syndrome coronavirus  sarscov the first known case was identified in wuhan china in december  the disease has since spread worldwide leading to an ongoing pandemicsymptoms of covid are variable but often include fever cough headache fatigue breathing difficulties and loss of smell and taste symptoms may begin one to fourteen days after exposure to the virus at least a third of people who are infected do not develop noticeable symptoms of those people who develop noticeable symptoms enough to be classed as patients most  develop mild to moderate symptoms up to mild pneumonia while  develop severe symptoms dyspnea hypoxia or more than  lung involvement on imaging and  suffer critical symptoms respiratory failure shock or multiorgan dysfunction older people are at a higher risk of developing severe symptoms some people continue to experience a range of effects long covid for months after recovery and damage to organs has been observed multiyear studies are underway to further investigate the longterm effects of the diseasetransmission of covid occurs when people are exposed to viruscontaining respiratory droplets and airborne particles exhaled by an infected person those particles may be inhaled or may reach the mouth nose or eyes of a person through touching or direct deposition ie being coughed on the risk of infection is highest when people are in close proximity for a long time but particles can be inhaled over longer distances particularly indoors in poorly ventilated and crowded spaces in those conditions small particles can remain suspended in the air for minutes to hours touching a contaminated surface or object may lead to infection although this does not contribute substantially to transmission people who are infected can transmit the virus to another person up to two days before they themselves show symptoms as can people who do not experience symptoms people remain infectious for up to ten days after the onset of symptoms in moderate cases and up to twenty days in severe casesseveral testing methods have been developed to diagnose the disease the standard diagnostic method is by detection of the virus' nucleic acid by realtime reverse transcription polymerase chain reaction rrtpcr transcriptionmediated amplification tma or by reverse transcription loopmediated isothermal amplification rtlamp from a nasopharyngeal swabpreventive measures include physical or social distancing quarantining ventilation of indoor spaces covering coughs and sneezes hand washing and keeping unwashed hands away from the face the use of face masks or coverings has been recommended in public settings to minimize the risk of transmissions several vaccines have been developed and many countries have initiated mass vaccination campaignsalthough work is underway to develop drugs that inhibit the virus the primary treatment is symptomatic management involves the treatment of symptoms supportive care isolation and experimental measures"

# %%
words = txt.split(' ')

# %%
words
# Out:
# ['coronavirus',
#  'disease',
#  '',
#  'covid',
#  'also',
#  'known',
#  'as',
#  'the',
#  'coronavirus',
#  'or',
#  'covid',
#  'is',
#  'a',
#  'contagious',
#  'disease',
#  'caused',
#  'by',
#  'severe',
#  'acute',
#  'respiratory',
#  'syndrome',
#  'coronavirus',
#  '',
#  'sarscov',
#  'the',
#  'first',
#  'known',
#  'case',
#  'was',
#  'identified',
#  'in',
#  'wuhan',
#  'china',
#  'in',
#  'december',
#  '',
#  'the',
#  'disease',
#  'has',
#  'since',
#  'spread',
#  'worldwide',
#  'leading',
#  'to',
#  'an',
#  'ongoing',
#  'pandemicsymptoms',
#  'of',
#  'covid',
#  'are',
#  'variable',
#  'but',
#  'often',
#  'include',
#  'fever',
#  'cough',
#  'headache',
#  'fatigue',
#  'breathing',
#  'difficulties',
#  'and',
#  'loss',
#  'of',
#  'smell',
#  'and',
#  'taste',
#  'symptoms',
#  'may',
#  'begin',
#  'one',
#  'to',
#  'fourteen',
#  'days',
#  'after',
#  'exposure',
#  'to',
#  'the',
#  'virus',
#  'at',
#  'least',
#  'a',
#  'third',
#  'of',
#  'people',
#  'who',
#  'are',
#  'infected',
#  'do',
#  'not',
#  'develop',
#  'noticeable',
#  'symptoms',
#  'of',
#  'those',
#  'people',
#  'who',
#  'develop',
#  'noticeable',
#  'symptoms',
#  'enough',
#  'to',
#  'be',
#  'classed',
#  'as',
#  'patients',
#  'most',
#  '',
#  'develop',
#  'mild',
#  'to',
#  'moderate',
#  'symptoms',
#  'up',
#  'to',
#  'mild',
#  'pneumonia',
#  'while',
#  '',
#  'develop',
#  'severe',
#  'symptoms',
#  'dyspnea',
#  'hypoxia',
#  'or',
#  'more',
#  'than',
#  '',
#  'lung',
#  'involvement',
#  'on',
#  'imaging',
#  'and',
#  '',
#  'suffer',
#  'critical',
#  'symptoms',
#  'respiratory',
#  'failure',
#  'shock',
#  'or',
#  'multiorgan',
#  'dysfunction',
#  'older',
#  'people',
#  'are',
#  'at',
#  'a',
#  'higher',
#  'risk',
#  'of',
#  'developing',
#  'severe',
#  'symptoms',
#  'some',
#  'people',
#  'continue',
#  'to',
#  'experience',
#  'a',
#  'range',
#  'of',
#  'effects',
#  'long',
#  'covid',
#  'for',
#  'months',
#  'after',
#  'recovery',
#  'and',
#  'damage',
#  'to',
#  'organs',
#  'has',
#  'been',
#  'observed',
#  'multiyear',
#  'studies',
#  'are',
#  'underway',
#  'to',
#  'further',
#  'investigate',
#  'the',
#  'longterm',
#  'effects',
#  'of',
#  'the',
#  'diseasetransmission',
#  'of',
#  'covid',
#  'occurs',
#  'when',
#  'people',
#  'are',
#  'exposed',
#  'to',
#  'viruscontaining',
#  'respiratory',
#  'droplets',
#  'and',
#  'airborne',
#  'particles',
#  'exhaled',
#  'by',
#  'an',
#  'infected',
#  'person',
#  'those',
#  'particles',
#  'may',
#  'be',
#  'inhaled',
#  'or',
#  'may',
#  'reach',
#  'the',
#  'mouth',
#  'nose',
#  'or',
#  'eyes',
#  'of',
#  'a',
#  'person',
#  'through',
#  'touching',
#  'or',
#  'direct',
#  'deposition',
#  'ie',
#  'being',
#  'coughed',
#  'on',
#  'the',
#  'risk',
#  'of',
#  'infection',
#  'is',
#  'highest',
#  'when',
#  'people',
#  'are',
#  'in',
#  'close',
#  'proximity',
#  'for',
#  'a',
#  'long',
#  'time',
#  'but',
#  'particles',
#  'can',
#  'be',
#  'inhaled',
#  'over',
#  'longer',
#  'distances',
#  'particularly',
#  'indoors',
#  'in',
#  'poorly',
#  'ventilated',
#  'and',
#  'crowded',
#  'spaces',
#  'in',
#  'those',
#  'conditions',
#  'small',
#  'particles',
#  'can',
#  'remain',
#  'suspended',
#  'in',
#  'the',
#  'air',
#  'for',
#  'minutes',
#  'to',
#  'hours',
#  'touching',
#  'a',
#  'contaminated',
#  'surface',
#  'or',
#  'object',
#  'may',
#  'lead',
#  'to',
#  'infection',
#  'although',
#  'this',
#  'does',
#  'not',
#  'contribute',
#  'substantially',
#  'to',
#  'transmission',
#  'people',
#  'who',
#  'are',
#  'infected',
#  'can',
#  'transmit',
#  'the',
#  'virus',
#  'to',
#  'another',
#  'person',
#  'up',
#  'to',
#  'two',
#  'days',
#  'before',
#  'they',
#  'themselves',
#  'show',
#  'symptoms',
#  'as',
#  'can',
#  'people',
#  'who',
#  'do',
#  'not',
#  'experience',
#  'symptoms',
#  'people',
#  'remain',
#  'infectious',
#  'for',
#  'up',
#  'to',
#  'ten',
#  'days',
#  'after',
#  'the',
#  'onset',
#  'of',
#  'symptoms',
#  'in',
#  'moderate',
#  'cases',
#  'and',
#  'up',
#  'to',
#  'twenty',
#  'days',
#  'in',
#  'severe',
#  'casesseveral',
#  'testing',
#  'methods',
#  'have',
#  'been',
#  'developed',
#  'to',
#  'diagnose',
#  'the',
#  'disease',
#  'the',
#  'standard',
#  'diagnostic',
#  'method',
#  'is',
#  'by',
#  'detection',
#  'of',
#  'the',
#  "virus'",
#  'nucleic',
#  'acid',
#  'by',
#  'realtime',
#  'reverse',
#  'transcription',
#  'polymerase',
#  'chain',
#  'reaction',
#  'rrtpcr',
#  'transcriptionmediated',
#  'amplification',
#  'tma',
#  'or',
#  'by',
#  'reverse',
#  'transcription',
#  'loopmediated',
#  'isothermal',
#  'amplification',
#  'rtlamp',
#  'from',
#  'a',
#  'nasopharyngeal',
#  'swabpreventive',
#  'measures',
#  'include',
#  'physical',
#  'or',
#  'social',
#  'distancing',
#  'quarantining',
#  'ventilation',
#  'of',
#  'indoor',
#  'spaces',
#  'covering',
#  'coughs',
#  'and',
#  'sneezes',
#  'hand',
#  'washing',
#  'and',
#  'keeping',
#  'unwashed',
#  'hands',
#  'away',
#  'from',
#  'the',
#  'face',
#  'the',
#  'use',
#  'of',
#  'face',
#  'masks',
#  'or',
#  'coverings',
#  'has',
#  'been',
#  'recommended',
#  'in',
#  'public',
#  'settings',
#  'to',
#  'minimize',
#  'the',
#  'risk',
#  'of',
#  'transmissions',
#  'several',
#  'vaccines',
#  'have',
#  'been',
#  'developed',
#  'and',
#  'many',
#  'countries',
#  'have',
#  'initiated',
#  'mass',
#  'vaccination',
#  'campaignsalthough',
#  'work',
#  'is',
#  'underway',
#  'to',
#  'develop',
#  'drugs',
#  'that',
#  'inhibit',
#  'the',
#  'virus',
#  'the',
#  'primary',
#  'treatment',
#  'is',
#  'symptomatic',
#  'management',
#  'involves',
#  'the',
#  'treatment',
#  'of',
#  'symptoms',
#  'supportive',
#  'care',
#  'isolation',
#  'and',
#  'experimental',
#  'measures']

# %%
vocab = list(set(words))
vocab
# Out:
# ['',
#  'patients',
#  'developing',
#  'sarscov',
#  'cough',
#  'many',
#  'occurs',
#  'longer',
#  'nasopharyngeal',
#  'disease',
#  'face',
#  'do',
#  'the',
#  'severe',
#  'in',
#  'eyes',
#  'over',
#  'primary',
#  'nose',
#  'ie',
#  'loopmediated',
#  'mass',
#  'for',
#  'casesseveral',
#  'but',
#  'caused',
#  'people',
#  'who',
#  'campaignsalthough',
#  'airborne',
#  'being',
#  'dyspnea',
#  'onset',
#  'realtime',
#  'covid',
#  'be',
#  'hands',
#  'exposed',
#  'may',
#  'treatment',
#  'before',
#  'suspended',
#  'can',
#  'china',
#  'themselves',
#  'damage',
#  'syndrome',
#  'respiratory',
#  'symptoms',
#  'indoors',
#  'imaging',
#  'does',
#  'recommended',
#  'through',
#  'they',
#  'include',
#  'lead',
#  'countries',
#  'drugs',
#  'risk',
#  'reverse',
#  'experience',
#  'noticeable',
#  'failure',
#  'another',
#  'critical',
#  'acute',
#  'away',
#  'has',
#  'detection',
#  'testing',
#  'mild',
#  'diagnose',
#  'although',
#  'leading',
#  'transcriptionmediated',
#  'isothermal',
#  'suffer',
#  'days',
#  'method',
#  'nucleic',
#  'often',
#  'breathing',
#  'distancing',
#  'several',
#  'keeping',
#  'also',
#  'december',
#  'particularly',
#  'pandemicsymptoms',
#  'methods',
#  'viruscontaining',
#  'person',
#  'this',
#  'since',
#  'not',
#  'older',
#  'wuhan',
#  'are',
#  'moderate',
#  'multiyear',
#  'highest',
#  'unwashed',
#  'vaccines',
#  'quarantining',
#  'infected',
#  'work',
#  'swabpreventive',
#  'spaces',
#  'first',
#  'after',
#  'exhaled',
#  'coverings',
#  'initiated',
#  'enough',
#  'difficulties',
#  'an',
#  'more',
#  'transmit',
#  'proximity',
#  'pneumonia',
#  'have',
#  'higher',
#  'been',
#  'smell',
#  'some',
#  'use',
#  'organs',
#  'coughs',
#  'least',
#  'infectious',
#  'surface',
#  'of',
#  'one',
#  'while',
#  'droplets',
#  'two',
#  'by',
#  'recovery',
#  'substantially',
#  'fourteen',
#  'transmission',
#  'isolation',
#  'effects',
#  'transmissions',
#  'multiorgan',
#  'at',
#  'range',
#  'known',
#  'contaminated',
#  'cases',
#  'shock',
#  'diseasetransmission',
#  'washing',
#  'develop',
#  'lung',
#  'touching',
#  'direct',
#  'as',
#  'supportive',
#  'involves',
#  'small',
#  'hypoxia',
#  'studies',
#  'social',
#  'poorly',
#  'physical',
#  'minimize',
#  'hours',
#  'spread',
#  'contribute',
#  'indoor',
#  'covering',
#  'virus',
#  'reach',
#  'crowded',
#  'case',
#  'continue',
#  'when',
#  'inhaled',
#  'fever',
#  'a',
#  'longterm',
#  'conditions',
#  'minutes',
#  'worldwide',
#  'classed',
#  'measures',
#  'from',
#  'masks',
#  "virus'",
#  'identified',
#  'amplification',
#  'vaccination',
#  'long',
#  'coronavirus',
#  'variable',
#  'developed',
#  'time',
#  'up',
#  'investigate',
#  'mouth',
#  'rtlamp',
#  'that',
#  'care',
#  'on',
#  'was',
#  'reaction',
#  'inhibit',
#  'standard',
#  'settings',
#  'coughed',
#  'contagious',
#  'underway',
#  'close',
#  'diagnostic',
#  'ten',
#  'remain',
#  'months',
#  'ongoing',
#  'third',
#  'polymerase',
#  'tma',
#  'fatigue',
#  'observed',
#  'ventilated',
#  'show',
#  'distances',
#  'public',
#  'acid',
#  'transcription',
#  'begin',
#  'involvement',
#  'to',
#  'dysfunction',
#  'ventilation',
#  'those',
#  'headache',
#  'chain',
#  'rrtpcr',
#  'sneezes',
#  'hand',
#  'management',
#  'exposure',
#  'experimental',
#  'most',
#  'is',
#  'deposition',
#  'object',
#  'twenty',
#  'taste',
#  'than',
#  'particles',
#  'or',
#  'symptomatic',
#  'further',
#  'loss',
#  'infection',
#  'air',
#  'and']

# %%
for word in vocab:
    if(word == 'KNOWN'.lower()):
        print(word)
# Out:
# known

# %%
def counter(word):
    
    c = 0
    for i in words:
        if (i == word):
            c += 1
            
    return c

# %%
word_counter = {}

for i in vocab:
    word_counter[i] = counter(i)

# %%
var = 0
word_to_int = {}
int_to_word = {}
for i in vocab:
    word_to_int[i] = var
    int_to_word[var] = i
    
    var += 1

# %%
word_to_int
# Out:
# {'': 0,
#  'patients': 1,
#  'developing': 2,
#  'sarscov': 3,
#  'cough': 4,
#  'many': 5,
#  'occurs': 6,
#  'longer': 7,
#  'nasopharyngeal': 8,
#  'disease': 9,
#  'face': 10,
#  'do': 11,
#  'the': 12,
#  'severe': 13,
#  'in': 14,
#  'eyes': 15,
#  'over': 16,
#  'primary': 17,
#  'nose': 18,
#  'ie': 19,
#  'loopmediated': 20,
#  'mass': 21,
#  'for': 22,
#  'casesseveral': 23,
#  'but': 24,
#  'caused': 25,
#  'people': 26,
#  'who': 27,
#  'campaignsalthough': 28,
#  'airborne': 29,
#  'being': 30,
#  'dyspnea': 31,
#  'onset': 32,
#  'realtime': 33,
#  'covid': 34,
#  'be': 35,
#  'hands': 36,
#  'exposed': 37,
#  'may': 38,
#  'treatment': 39,
#  'before': 40,
#  'suspended': 41,
#  'can': 42,
#  'china': 43,
#  'themselves': 44,
#  'damage': 45,
#  'syndrome': 46,
#  'respiratory': 47,
#  'symptoms': 48,
#  'indoors': 49,
#  'imaging': 50,
#  'does': 51,
#  'recommended': 52,
#  'through': 53,
#  'they': 54,
#  'include': 55,
#  'lead': 56,
#  'countries': 57,
#  'drugs': 58,
#  'risk': 59,
#  'reverse': 60,
#  'experience': 61,
#  'noticeable': 62,
#  'failure': 63,
#  'another': 64,
#  'critical': 65,
#  'acute': 66,
#  'away': 67,
#  'has': 68,
#  'detection': 69,
#  'testing': 70,
#  'mild': 71,
#  'diagnose': 72,
#  'although': 73,
#  'leading': 74,
#  'transcriptionmediated': 75,
#  'isothermal': 76,
#  'suffer': 77,
#  'days': 78,
#  'method': 79,
#  'nucleic': 80,
#  'often': 81,
#  'breathing': 82,
#  'distancing': 83,
#  'several': 84,
#  'keeping': 85,
#  'also': 86,
#  'december': 87,
#  'particularly': 88,
#  'pandemicsymptoms': 89,
#  'methods': 90,
#  'viruscontaining': 91,
#  'person': 92,
#  'this': 93,
#  'since': 94,
#  'not': 95,
#  'older': 96,
#  'wuhan': 97,
#  'are': 98,
#  'moderate': 99,
#  'multiyear': 100,
#  'highest': 101,
#  'unwashed': 102,
#  'vaccines': 103,
#  'quarantining': 104,
#  'infected': 105,
#  'work': 106,
#  'swabpreventive': 107,
#  'spaces': 108,
#  'first': 109,
#  'after': 110,
#  'exhaled': 111,
#  'coverings': 112,
#  'initiated': 113,
#  'enough': 114,
#  'difficulties': 115,
#  'an': 116,
#  'more': 117,
#  'transmit': 118,
#  'proximity': 119,
#  'pneumonia': 120,
#  'have': 121,
#  'higher': 122,
#  'been': 123,
#  'smell': 124,
#  'some': 125,
#  'use': 126,
#  'organs': 127,
#  'coughs': 128,
#  'least': 129,
#  'infectious': 130,
#  'surface': 131,
#  'of': 132,
#  'one': 133,
#  'while': 134,
#  'droplets': 135,
#  'two': 136,
#  'by': 137,
#  'recovery': 138,
#  'substantially': 139,
#  'fourteen': 140,
#  'transmission': 141,
#  'isolation': 142,
#  'effects': 143,
#  'transmissions': 144,
#  'multiorgan': 145,
#  'at': 146,
#  'range': 147,
#  'known': 148,
#  'contaminated': 149,
#  'cases': 150,
#  'shock': 151,
#  'diseasetransmission': 152,
#  'washing': 153,
#  'develop': 154,
#  'lung': 155,
#  'touching': 156,
#  'direct': 157,
#  'as': 158,
#  'supportive': 159,
#  'involves': 160,
#  'small': 161,
#  'hypoxia': 162,
#  'studies': 163,
#  'social': 164,
#  'poorly': 165,
#  'physical': 166,
#  'minimize': 167,
#  'hours': 168,
#  'spread': 169,
#  'contribute': 170,
#  'indoor': 171,
#  'covering': 172,
#  'virus': 173,
#  'reach': 174,
#  'crowded': 175,
#  'case': 176,
#  'continue': 177,
#  'when': 178,
#  'inhaled': 179,
#  'fever': 180,
#  'a': 181,
#  'longterm': 182,
#  'conditions': 183,
#  'minutes': 184,
#  'worldwide': 185,
#  'classed': 186,
#  'measures': 187,
#  'from': 188,
#  'masks': 189,
#  "virus'": 190,
#  'identified': 191,
#  'amplification': 192,
#  'vaccination': 193,
#  'long': 194,
#  'coronavirus': 195,
#  'variable': 196,
#  'developed': 197,
#  'time': 198,
#  'up': 199,
#  'investigate': 200,
#  'mouth': 201,
#  'rtlamp': 202,
#  'that': 203,
#  'care': 204,
#  'on': 205,
#  'was': 206,
#  'reaction': 207,
#  'inhibit': 208,
#  'standard': 209,
#  'settings': 210,
#  'coughed': 211,
#  'contagious': 212,
#  'underway': 213,
#  'close': 214,
#  'diagnostic': 215,
#  'ten': 216,
#  'remain': 217,
#  'months': 218,
#  'ongoing': 219,
#  'third': 220,
#  'polymerase': 221,
#  'tma': 222,
#  'fatigue': 223,
#  'observed': 224,
#  'ventilated': 225,
#  'show': 226,
#  'distances': 227,
#  'public': 228,
#  'acid': 229,
#  'transcription': 230,
#  'begin': 231,
#  'involvement': 232,
#  'to': 233,
#  'dysfunction': 234,
#  'ventilation': 235,
#  'those': 236,
#  'headache': 237,
#  'chain': 238,
#  'rrtpcr': 239,
#  'sneezes': 240,
#  'hand': 241,
#  'management': 242,
#  'exposure': 243,
#  'experimental': 244,
#  'most': 245,
#  'is': 246,
#  'deposition': 247,
#  'object': 248,
#  'twenty': 249,
#  'taste': 250,
#  'than': 251,
#  'particles': 252,
#  'or': 253,
#  'symptomatic': 254,
#  'further': 255,
#  'loss': 256,
#  'infection': 257,
#  'air': 258,
#  'and': 259}

# %%
word_to_int['the']
# Out:
# 12

# %%
#TEXT ENCODING

word_cloud = ''

for word in words:
    word_cloud += str(word_to_int[word]) + ' '

print(word_cloud)
# Out:
# 195 9 0 34 86 148 158 12 195 253 34 246 181 212 9 25 137 13 66 47 46 195 0 3 12 109 148 176 206 191 14 97 43 14 87 0 12 9 68 94 169 185 74 233 116 219 89 132 34 98 196 24 81 55 180 4 237 223 82 115 259 256 132 124 259 250 48 38 231 133 233 140 78 110 243 233 12 173 146 129 181 220 132 26 27 98 105 11 95 154 62 48 132 236 26 27 154 62 48 114 233 35 186 158 1 245 0 154 71 233 99 48 199 233 71 120 134 0 154 13 48 31 162 253 117 251 0 155 232 205 50 259 0 77 65 48 47 63 151 253 145 234 96 26 98 146 181 122 59 132 2 13 48 125 26 177 233 61 181 147 132 143 194 34 22 218 110 138 259 45 233 127 68 123 224 100 163 98 213 233 255 200 12 182 143 132 12 152 132 34 6 178 26 98 37 233 91 47 135 259 29 252 111 137 116 105 92 236 252 38 35 179 253 38 174 12 201 18 253 15 132 181 92 53 156 253 157 247 19 30 211 205 12 59 132 257 246 101 178 26 98 14 214 119 22 181 194 198 24 252 42 35 179 16 7 227 88 49 14 165 225 259 175 108 14 236 183 161 252 42 217 41 14 12 258 22 184 233 168 156 181 149 131 253 248 38 56 233 257 73 93 51 95 170 139 233 141 26 27 98 105 42 118 12 173 233 64 92 199 233 136 78 40 54 44 226 48 158 42 26 27 11 95 61 48 26 217 130 22 199 233 216 78 110 12 32 132 48 14 99 150 259 199 233 249 78 14 13 23 70 90 121 123 197 233 72 12 9 12 209 215 79 246 137 69 132 12 190 80 229 137 33 60 230 221 238 207 239 75 192 222 253 137 60 230 20 76 192 202 188 181 8 107 187 55 166 253 164 83 104 235 132 171 108 172 128 259 240 241 153 259 85 102 36 67 188 12 10 12 126 132 10 189 253 112 68 123 52 14 228 210 233 167 12 59 132 144 84 103 121 123 197 259 5 57 121 113 21 193 28 106 246 213 233 154 58 203 208 12 173 12 17 39 246 254 242 160 12 39 132 48 159 204 142 259 244 187

# %%
#TEXT DECODING

decoded_text = ''''''

for num in word_cloud.split():
    num = int(num)
    decoded_text += int_to_word[num] + ' '
    
print(decoded_text)
# Out:
# coronavirus disease  covid also known as the coronavirus or covid is a contagious disease caused by severe acute respiratory syndrome coronavirus  sarscov the first known case was identified in wuhan china in december  the disease has since spread worldwide leading to an ongoing pandemicsymptoms of covid are variable but often include fever cough headache fatigue breathing difficulties and loss of smell and taste symptoms may begin one to fourteen days after exposure to the virus at least a third of people who are infected do not develop noticeable symptoms of those people who develop noticeable symptoms enough to be classed as patients most  develop mild to moderate symptoms up to mild pneumonia while  develop severe symptoms dyspnea hypoxia or more than  lung involvement on imaging and  suffer critical symptoms respiratory failure shock or multiorgan dysfunction older people are at a higher risk of developing severe symptoms some people continue to experience a range of effects long covid for months after recovery and damage to organs has been observed multiyear studies are underway to further investigate the longterm effects of the diseasetransmission of covid occurs when people are exposed to viruscontaining respiratory droplets and airborne particles exhaled by an infected person those particles may be inhaled or may reach the mouth nose or eyes of a person through touching or direct deposition ie being coughed on the risk of infection is highest when people are in close proximity for a long time but particles can be inhaled over longer distances particularly indoors in poorly ventilated and crowded spaces in those conditions small particles can remain suspended in the air for minutes to hours touching a contaminated surface or object may lead to infection although this does not contribute substantially to transmission people who are infected can transmit the virus to another person up to two days before they themselves show symptoms as can people who do not experience symptoms people remain infectious for up to ten days after the onset of symptoms in moderate cases and up to twenty days in severe casesseveral testing methods have been developed to diagnose the disease the standard diagnostic method is by detection of the virus' nucleic acid by realtime reverse transcription polymerase chain reaction rrtpcr transcriptionmediated amplification tma or by reverse transcription loopmediated isothermal amplification rtlamp from a nasopharyngeal swabpreventive measures include physical or social distancing quarantining ventilation of indoor spaces covering coughs and sneezes hand washing and keeping unwashed hands away from the face the use of face masks or coverings has been recommended in public settings to minimize the risk of transmissions several vaccines have been developed and many countries have initiated mass vaccination campaignsalthough work is underway to develop drugs that inhibit the virus the primary treatment is symptomatic management involves the treatment of symptoms supportive care isolation and experimental measures
